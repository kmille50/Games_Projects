# %%
import sys
import math
from random import random

x = ["+7", "-10","+13","+8","+4","-7","-12","-3","+3","-9","+6","-1", "-6", "+7"]
print(x)
# Out:
# ['+7', '-10', '+13', '+8', '+4', '-7', '-12', '-3', '+3', '-9', '+6', '-1', '-6', '+7']

# %%
from random import randint

N = randint(0, 10000)
#t = [randint(-273, 5526) for p in range(0, N)]

t = [7,-10,13,8,4,-7,-12,-3,3,-9,6,-6,7]

# %%
def temp (x, y):
    if x == 0: 
        return print("0")
    else :
        return print(min(y, key = lambda x: abs(x-0))) #min(y, key=abs)

# %%
temp(N, t)
# Out:
# -3
