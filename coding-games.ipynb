# %%
import sys
import math
from random import random

x = ["+7", "-10","+13","+8","+4","-7","-12","-3","+3","-9","+6","-1", "-6", "+7"]
print(x)
# Out:
# ['+7', '-10', '+13', '+8', '+4', '-7', '-12', '-3', '+3', '-9', '+6', '-1', '-6', '+7']

# %%
from random import randint

N = randint(0, 9999)
#temp = [randint(-273, 5526) for p in range(0, N)]

temp = [7,-10,13,8,4,-7,-12,-3,3,-9,6,-6,7]

# %%
def min_temp (N, temp):
    if N == 0: 
        return print("0")
    else :
        return print(min(temp, key=abs))

# %%
min_temp(N, temp)
# Out:
# -3
